# %% [raw]
# création de défauts synthétiques
# - récupération de supports vides, de supports conformes et de supports non conformes
#
# - extraction de motifs vides sur les uspports vides
#
# - extraction de motifs de défaut sur les supports non conformes
#     segmentation des défauts
#
# - réalisation de supports vides
#     par combinaison de supports vide
#     par superposition de motif vide sur un support non vide
#
# - looping de :
#     réorientation aléatoire de motif de défaut
#     sélection aléatoire de support vide
#     superposition du motif sur le support vide

# %%
import os
import glob
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image 
import random

# %%
glob.glob(r"D:\train_double_tape_LH03\NC\*.bmp")
# Out:
# ['D:\\train_double_tape_LH03\\NC\\LH_03043_03_OK.bmp',
#  'D:\\train_double_tape_LH03\\NC\\LH_03195_03_OK (2).bmp',
#  'D:\\train_double_tape_LH03\\NC\\LH_03891_03_OK.bmp',
#  'D:\\train_double_tape_LH03\\NC\\LH_04363_03_OK.bmp',
#  'D:\\train_double_tape_LH03\\NC\\LH_06379_03_OK (2).bmp',
#  'D:\\train_double_tape_LH03\\NC\\LH_06435_03_OK (2).bmp',
#  'D:\\train_double_tape_LH03\\NC\\LH_06875_03_OK (2).bmp',
#  'D:\\train_double_tape_LH03\\NC\\LH_07611_03_OK (2).bmp',
#  'D:\\train_double_tape_LH03\\NC\\LH_07867_03_OK (2).bmp',
#  'D:\\train_double_tape_LH03\\NC\\LH_09363_03_OK.bmp',
#  'D:\\train_double_tape_LH03\\NC\\LH_09779_03_OK (2).bmp',
#  'D:\\train_double_tape_LH03\\NC\\LH_11787_03_OK.bmp',
#  'D:\\train_double_tape_LH03\\NC\\LH_15011_03_OK (2).bmp',
#  'D:\\train_double_tape_LH03\\NC\\LH_15779_03_OK (2).bmp',
#  'D:\\train_double_tape_LH03\\NC\\LH_18427_03_OK.bmp',
#  'D:\\train_double_tape_LH03\\NC\\LH_18771_03_OK.bmp',
# ...

# %%
# récupération d'une fenêtre de l'image où se trouve la portion à extraire
# Chemin de l'image
image_path = r"data\NC\LH_11371_03_OK.bmp"#r'data/NC/LH_03043_03_OK_double_tape.bmp'

# Vérification du chemin
assert os.path.exists(image_path), "Le fichier n'existe pas au chemin spécifié"

# Chargement de l'image
image = cv2.imread(image_path)
assert image is not None, "L'image n'a pas pu être lue"

# Recadrage
img_cropped = image[0:0+60, 25:25+40]  # Ajuster les valeurs selon vos besoins ATTENTION

# Affichage de l'image 
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Image originale")
plt.show()

# Affichage de l'image recadrée
plt.imshow(cv2.cvtColor(img_cropped, cv2.COLOR_BGR2RGB))
plt.title("Image recadrée")
plt.show()

# %%
# segmentation de l'image
# foreground extraction using GrabCut algorithm

# image source for extraction
image = img_cropped

# create a simple mask image similar
# to the loaded image, with the 
# shape and return type
mask = np.zeros(image.shape[:2], np.uint8)

# specify the background and foreground model
# using numpy the array is constructed of 1 row
# and 65 columns, and all array elements are 0
# Data type for the array is np.float64 (default)
backgroundModel = np.zeros((1, 65), np.float64)
foregroundModel = np.zeros((1, 65), np.float64)

# define the Region of Interest (ROI)
# as the coordinates of the rectangle
# where the values are entered as
# (startingPoint_x, startingPoint_y, width, height)
# these coordinates are according to the input image
# it may vary for different images
rectangle = (0, 0, 35, 50)

# apply the grabcut algorithm with appropriate
# values as parameters, number of iterations = 3 
# cv2.GC_INIT_WITH_RECT is used because
# of the rectangle mode is used 
cv2.grabCut(image, mask, rectangle, 
			backgroundModel, foregroundModel,
			3, cv2.GC_INIT_WITH_RECT)

# In the new mask image, pixels will 
# be marked with four flags 
# four flags denote the background / foreground 
# mask is changed, all the 0 and 2 pixels 
# are converted to the background
# mask is changed, all the 1 and 3 pixels
# are now the part of the foreground
# the return type is also mentioned,
# this gives us the final mask
mask2 = np.where((mask == 2)|(mask == 0), 0, 1).astype('uint8')

# The final mask is multiplied with 
# the input image to give the segmented image.
image_segmented = image * mask2[:, :, np.newaxis]

# output segmented image with colorbar
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#plt.axis('off')

# Display the segmented image
plt.subplot(1, 2, 2)
plt.title('Segmented Image')
plt.imshow(cv2.cvtColor(image_segmented, cv2.COLOR_BGR2RGB))
#plt.axis('off')

plt.show()

cv2.imwrite("img_seg.bmp", image_segmented)
cv2.imwrite("empty_seg.bmp", image)
# Out:
# True

# %%
# OPTIONEL
# réorienter l'image pour permettr ed'enelever l'anomalie
# extracted image
extracted_image = Image.open("img_seg.bmp") 

# move image
shift_x = 0
shift_y = 5

rotated_image = extracted_image.rotate(0, translate=(shift_x, shift_y))
rotated_image = rotated_image.rotate(-20)

plt.imshow(rotated_image)

# %%
# OPTIONEL
# enlever l'anomalie sur l'image segmentée
# Charger l'image avec PIL
image = rotated_image

# Convertir l'image en tableau NumPy
image_array = np.array(image)

# Colorier en noir les pixels où x < 12
# Cela signifie qu'on définit tous les pixels sur les 10 premières colonnes à [0, 0, 0] (noir)
image_array[:, :9] = [0, 0, 0]  # Pour une image RGB, [0, 0, 0] est noir

# Convertir le tableau NumPy modifié de retour en image PIL
modified_image = Image.fromarray(image_array)

# Afficher l'image modifiée
plt.imshow(modified_image)
plt.show()

modified_image.save("crop.bmp")

# %%
modified_image = Image.fromarray(image_segmented)

# %%
# collage de l'extrait réorienté sur le fond vide 
angle = random.randrange(-30, 30, 1)
shift_x = random.randrange(-5, 5, 1)
shift_y = random.randrange(-5, 5, 1)
modified_image2 = modified_image.rotate(angle, translate=(shift_x, shift_y))

# Charger l'extracted image
extract_ = modified_image2.convert("RGBA")#Image.open("crop.bmp").convert("RGBA")  # Convertir en RGBA pour gérer la transparence

# Créer une image du paysage vide (par exemple fond blanc)
background = Image.open(r"data/NC/LH_02219_03_OK (3)_empty.bmp")

# Rendre transparent le fond noir du extract_
# On parcourt chaque pixel et on rend transparent ceux qui sont noirs ou proches du noir
extract_array = extract_.load()  # Accéder aux pixels de l'image

for y in range(extract_.height):
    for x in range(extract_.width):
        r, g, b, a = extract_array[x, y]  # Lire la couleur du pixel
        if r < 50 and g < 50 and b < 50:  # Si le pixel est noir ou proche du noir
            extract_array[x, y] = (0, 0, 0, 0)  # Rendre ce pixel transparent

# Définir la position où coller le extract_ sur le paysage - ATTENTION ordre inversé pour le x et le y
position = (35, 10)

# Coller l'image du extract_ sur le paysage
background.paste(extract_, position, extract_)  # Utilise la transparence du extract_

# Sauvegarder l'image résultante
background.save(f"synth_defect11.bmp")

# Afficher l'image résultante
plt.imshow(background)

# %%
# make an empty image
img1 = plt.imread(r"data\NC\LH_02219_03_OK (3)_empty.bmp")
img2 = plt.imread(r"C:\Users\John\Desktop\défauts_synthétiques\data\NC\LH_11371_03_OK.bmp")

# %%
# Supposons que img1 et img2 sont des tableaux NumPy de même taille
# Normalisation ou transformation des images (division par 2 ici)
img1 = (img1 // 2).astype('uint8')
img2 = (img2 // 2).astype('uint8')

# Additionner les images
result = img1 + img2  # Cela combine les pixels des deux images

# Afficher le résultat
plt.imshow(result)
plt.show()

# %%
empty_seg = Image.open("data\stickers\empty_seg.bmp")

# %%
# collage de l'extrait vide sur une image avec un sticker pour créer une image vide
angle = random.randrange(-30, 30, 1)
shift_x = random.randrange(-5, 5, 1)
shift_y = random.randrange(-5, 5, 1)
modified_image2 = empty_seg#modified_image.rotate(angle, translate=(shift_x, shift_y))

# Charger l'extracted image
extract_ = modified_image2.convert("RGBA")#Image.open("crop.bmp").convert("RGBA")  # Convertir en RGBA pour gérer la transparence

# Créer une image du paysage vide (par exemple fond blanc)
background = Image.open(r"data/NC/LH_02219_03_OK (3)_empty.bmp")#r"data\NC\LH_11371_03_OK.bmp")#

# Rendre transparent le fond noir du extract_
# On parcourt chaque pixel et on rend transparent ceux qui sont noirs ou proches du noir
extract_array = extract_.load()  # Accéder aux pixels de l'image

for y in range(extract_.height):
    for x in range(extract_.width):
        r, g, b, a = extract_array[x, y]  # Lire la couleur du pixel
        if r < 50 and g < 50 and b < 50:  # Si le pixel est noir ou proche du noir
            extract_array[x, y] = (0, 0, 0, 0)  # Rendre ce pixel transparent

# Définir la position où coller le extract_ sur le paysage - ATTENTION ordre inversé pour le x et le y
position = (25, 0)

# Coller l'image du extract_ sur le paysage
background.paste(extract_, position, extract_)  # Utilise la transparence du extract_

# Sauvegarder l'image résultante
background.save(f"empty_synth.bmp")

# Afficher l'image résultante
plt.imshow(background)
